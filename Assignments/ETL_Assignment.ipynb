# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv(r"C:\Users\Administrator\Downloads\sales_data.csv")
data
# Out:
#    OrderId     Product  Price
# 0        1      Laptop   5000
# 1        2       Phone  20000
# 2        3      Tablet  30000
# 3        4     Monitor  15000
# 4        5    Keyboard   2000
# 5        6       Mouse   1000
# 6        7     Printer  12000
# 7        8  Headphones   3000
# 8        9      Camera  25000
# 9       10     Speaker   4000

# %%
data.isna().sum()
# Out:
# OrderId    0
# Product    0
# Price      0
# dtype: int64

# %%
data = data.dropna()
