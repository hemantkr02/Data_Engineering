# %%
import os
os.mkdir("Hello")

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Administrator'

# %%
os.chdir("/Users/Administrator/Hello")

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Administrator\\Hello'

# %%
import os

os.getenv("Users/Adminstrator/Hello")
lst = open("goodmorning.txt","w")
lst.write("hello goodmorning \n")
lst.write("how are you")
lst.close()

# %%
#Read the file
lst = open("goodmorning.txt","r")
lst.readlines()
# Out:
# ['hello goodmorning \n', 'how are you']

# %%
lst.close()

# %%
#remove the file
os.remove("goodmorning.txt")

# %%
os._exit(0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 os._exit(0)
#
# NameError: name 'os' is not defined

# %%
import os
os.rmdir('/Users/Administrator/Hello')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[5], line 2
#       1 import os
# ----> 2 os.rmdir('/Users/Administrator/Hello')
#
# FileNotFoundError: [WinError 2] The system cannot find the file specified: '/Users/Administrator/Hello'

# %%
# rmdir is being used to delete empty dir. to delete non empty dir rmdir() inside the shutil module

# %%
import shutil
#os.mkdir("file")
os.chdir("/Users/Administrator/Hello")
lst = open("goodmorning.txt","w")
lst.write("how are you")
lst.close()

# %%
shutil.rmtree("/Users/Administrator/Hello")
