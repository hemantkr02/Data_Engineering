# %%
def show_name(name):
    '''
    this function show name
    '''
    print("name is " +str(name))
show_name('hemant')
# Out:
# name is hemant

# %%
def get_sum(lst):
    '''
    this function returns sum of all elements in list
    '''
    all = 0
    for num in lst:
        all+=num
        print(all)
    return all
lst1 = get_sum([1,2,3,4])
print(get_sum.__doc__)
#print(all)
# Out:
# 1
# 3
# 6
# 10
#
#     this function returns sum of all elements in list

# %%
# Assignment : why we cannot call the local variable from outside

# %%
#ASSESSMENT

# %%
def factorial(num):
    # to find the factorial of number
        if num==1:
            return 1
        else:
            return num*factorial(num-1)
            
factorial(3)
# Out:
# 6

# %%
# Inbuilt function

# %%
#enumerate()
# enumerate(iterable, start=0)
lst = [10,20,30,40,50]
for index, num in enumerate(lst,start=0):
    print("index {0} has value {1}". format(index,num))
# Out:
# index 0 has value 10
# index 1 has value 20
# index 2 has value 30
# index 3 has value 40
# index 4 has value 50

# %%
def positive(num):
    if num>0: return num
positive(3)
# Out:
# 3

# %%
lst1=range(-10,10)
#lst2 = list(filter(positive,lst1))
lst2=list(filter(lambda x:x>0, lst1))

# %%
squared = list(map(lambda x:x**2, [1,2,3,4]))
print (squared)
# Out:
# [1, 4, 9, 16]

# %%
#with reduce
from functools import reduce
product=1
lst=[1,2,3,4]
def multiply(x,y):
    return x*y;
product = reduce(multiply,lst)

# %%
lst =[1,2,3,4]
product = reduce(lambda x,y:x*y, lst)
print(product)
# Out:
# 24

# %%
#def say(x=1,y):
#def say(x,y):
#def say(x,y=1):
#def say(x=1,y=1):
def say(x,y,z=4):

    #prod = x+y
    prod = x+y+z
    return prod

say(1,2)
#say(2,z=5)
# Out:
# 7

# %%
def lst (**kwargs):
    if kwargs:
        print ("contact {0},{1},{2},{3}".format(kwargs['name'],kwargs['mob'],kwargs['add'],kwargs['course']))
lst(name='hemant', mob=2828929,add='banglore',course='data')
# Out:
# contact hemant,2828929,banglore,data

# %%
#arbitrary argument: it all to pass number of arguments pass into a function

def lst(*names):
    print(names)
    for lst2 in names:
        print("Name {0}".format(lst2))
lst('hem','abhi','anand','1')
# Out:
# ('hem', 'abhi', 'anand', '1')
# Name hem
# Name abhi
# Name anand
# Name 1

# %%
#TOPIC: CLASSES and OBjects

# %%
class hello:
    hi='goodmorning'
test=hello()
test1=hello()
print(test.hi)
print(test1.hi) #calling variable from obj
print(hello.hi) # calling variable by classname
hello.hi="bye"
print(hello.hi)
# Out:
# goodmorning
# goodmorning
# goodmorning
# bye

# %%
class member:
    def __init__(self, name,age,position):
        self.name = name
        self.age = age
        self.position = position
    def hi(self, name, age):
        self.name=name
        self.age=age

test = member("hemu", 28, "office")
test1 = member("abhi", 29, "blr")
print(test.name)
print(test.age)
print(test.position)
print(test1.name)
print(test1.age)
# Out:
# hemu
# 28
# office
# abhi
# 29

# %%
class member:
    def __init__(self, name, age, position):
        self.name = name
        self.age = age
        self.position = position
    def testfun(self):
        print("Hello my name is "+self.name)

m1 = member("roger", 45, "soldier")
print(m1.name)
print(m1.age)
print(m1.position)
m1.testfun()
# Out:
# roger
# 45
# soldier
# Hello my name is roger

# %%
class person:
    def __init__(hemant, name, age):
        hemant.name = name
        hemant.age = age
    def func(xyz):
        print("hello my name is"+xyz.name)

p = person("Kumar", 23)
p.func()
# Out:
# hello my name isKumar

# %%
class xyz:
    print("ayz is parent class")
class abc(xyz):
    print("abc is child class of xyz")
# Out:
# ayz is parent class
# abc is child class of xyz

# %%
'''class sports:
    def __init__(self,model,color,cost):
        self.__model
        self.__color
        self.__cost
        
    def getmodel(self):
        return self.__model
    def setmodel(self,model):
        self.__model = model
        
    def getcolor(self):
        return self.__color
    def setcolor(self,color):
        self.__color = color
    def getcost(self):
        return self.__cost
    def setcost(self,cost):
        self.__cost=cost
class shoes(sports):
    def __init__(self, model, color, cost,brand):
        super().__init__(model, color, cost)
        self.__brand=brand
    sh1=shoes("shoes", "black", "2345", "huh")
    print(sh1.getModel())
    sh2= shoes("shoes", "blue", "16728", "hhh")'''
# Out:
# 'class sports:\n    def __init__(self,model,color,cost):\n        self.__model\n        self.__\n        \n    def getmodel(self):\n        return self.__model\n    def setmodel(self,model):\n        self.__model = model\n        \n    def getcolor(self):\n        return self.__color\n    def setcolor(self,color):\n        self.__color = color\n    def getcost(self):\n        return self.__cost\n    def setcost(self,cost):\n        self.__cost=cost\nclass shoes(sports):\n    def __init__(self, model, color, cost,brand):\n        super().__init__(model, color, cost)\n        self.__brand=brand\n    sh1=shoes("shoes", "black", "2345", "huh")\n    print(sh1.getModel())\n    sh2= shoes("shoes", "blue", "16728", "hhh")'

# %%
#Runtime Error and Compile time Error

# %%
dir(__builtins__)
# Out:
# ['ArithmeticError',
#  'AssertionError',
#  'AttributeError',
#  'BaseException',
#  'BaseExceptionGroup',
#  'BlockingIOError',
#  'BrokenPipeError',
#  'BufferError',
#  'BytesWarning',
#  'ChildProcessError',
#  'ConnectionAbortedError',
#  'ConnectionError',
#  'ConnectionRefusedError',
#  'ConnectionResetError',
#  'DeprecationWarning',
#  'EOFError',
#  'Ellipsis',
#  'EncodingWarning',
#  'EnvironmentError',
#  'Exception',
#  'ExceptionGroup',
#  'False',
#  'FileExistsError',
#  'FileNotFoundError',
#  'FloatingPointError',
#  'FutureWarning',
#  'GeneratorExit',
#  'IOError',
#  'ImportError',
#  'ImportWarning',
#  'IndentationError',
#  'IndexError',
#  'InterruptedError',
#  'IsADirectoryError',
#  'KeyError',
#  'KeyboardInterrupt',
#  'LookupError',
#  'MemoryError',
#  'ModuleNotFoundError',
#  'NameError',
#  'None',
#  'NotADirectoryError',
#  'NotImplemented',
#  'NotImplementedError',
#  'OSError',
#  'OverflowError',
#  'PendingDeprecationWarning',
# ...

# %%
import sys
lst = ['b',0,2]
for entry in lst:
    try:
        print("value is:", entry)
        k = 1/int(entry)
    except:
        print("oops", sys.exc_info(),"occured")
        print("next")
        print("********")
print("the reciprocal of", entry, "is", k)
# Out:
# value is: b
# oops (<class 'ValueError'>, ValueError("invalid literal for int() with base 10: 'b'"), <traceback object at 0x000002B08EEB5200>) occured
# next
# ********
# value is: 0
# oops (<class 'ZeroDivisionError'>, ZeroDivisionError('division by zero'), <traceback object at 0x000002B08EEB64C0>) occured
# next
# ********
# value is: 2
# the reciprocal of 2 is 0.5

# %%
import sys
lst = ['hemant', 'abhishek', 'anand', 'kush']
for i in lst:
    try:
        if i == 'kush':
            print("odd one out")
    except:
        print('oops', sys.exc_info())
# Out:
# odd one out

# %%
import sys
def openfile(file):
    try:
        open(file)
    except:
        print('oops', sys.exc_info())
openfile(filename)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 7
#       5     except:
#       6         print('oops', sys.exc_info())
# ----> 7 openfile(filename)
#
# NameError: name 'filename' is not defined

# %%
import sys
lst = ['b',0,2]
for entry in lst:
    try:
        print("+++++++++++++++")
        print("value is :", entry)
        k = 1/int(entry)
    except(ValueError):
        print("This is a valueerror.")
    except(ZeroDivisionError):
        print("it is divide by zero error")
    except:
        print("other Error")
print("The reciprocal of", entry, "is", k)
# Out:
# +++++++++++++++
# value is : b
# This is a valueerror.
# +++++++++++++++
# value is : 0
# it is divide by zero error
# +++++++++++++++
# value is : 2
# The reciprocal of 2 is 0.5

# %%
raise KeyboardInterrupt
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 raise KeyboardInterrupt
#
# KeyboardInterrupt:

# %%
raise MemoryError("this is memory error")
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 raise MemoryError("this is memory error")
#
# MemoryError: this is memory error

# %%
try:
    num = int(input("enter a positive number"))
    if num <= 0:
        raise ValueError("wrong number")
except ValueError as e:
    print(e)
# Out:
# enter a positive number -1
# wrong number

# %%
try:
    num = int(input("enter a positive number"))
    if num <= 0:
        raise MemoryError("No Space")
except MemoryError as e:
    print(e)
# Out:
# enter a positive number -1
# No Space

# %%
import os
#os.chdir('/users/dell/desktop')
try:
    f=open('prwa.txt')
finally:
    print("final closed")
    f.close()
# Out:
# final closed
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[22], line 4
#       3 try:
# ----> 4     f=open('prwa.txt')
#       5 finally:
#
# File C:\Program Files\Python312\Lib\site-packages\IPython\core\interactiveshell.py:324, in _modified_open(file, *args, **kwargs)
#     318     raise ValueError(
#     319         f"IPython won't let you open fd={file} by default "
#     320         "as it is likely to crash IPython. If you know what you are doing, "
#     321         "you can use builtins' open."
#     322     )
# --> 324 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'prwa.txt'
#
# During handling of the above exception, another exception occurred:
#
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 7
#       5 finally:
#       6     print("final closed")
# ...

# %%
import logging
logging.basicConfig(level=logging.INFO)
logging.debug("this is a debug message")
logging.info("App started")
logging.warning("showing warning")
logging.error("error occured")
logging.critical("critical issue")
# Out:
# INFO:root:App started
# WARNING:root:showing warning
# ERROR:root:error occured
# CRITICAL:root:critical issue

# %%
import logging
logging.basicConfig(
    
    level = logging.INFO,
    format = '%(asctime)s - %(levelname)s - %(message)s'
)

# %%
import logging
logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(levelname)s - %(message)s',
    filename='app.log',
    filemode='a'
)

# %%
try:
    num1 = int(input("Enter the first number"))
    num2 = int(input("Enter the second number"))
    
    print("Select operation: +  -  *  /")
    op = input("Enter operation: ")
    
    if op == '+':
        result = num1+num2
        print(f"Result: {num1} + {num2} = {result}")
    elif op == '-':
        result = num1-num2
        print(f"Result: {num1} - {num2} = {result}")
    elif op == '*':
        result = num1*num2
        print(f"Result: {num1} * {num2} = {result}")
    elif op == '/':
            if num2 == 0:
                print("Error: Division by zero ")
            else:
                result = num1 / num2
                print(f"Result: {num1} / {num2} = {result}")
    
    else:
        print("Invalid operation")
    
except ValueError:
    print("Invalid input, only integer input are valid")
# Out:
# Enter the first number j
# Invalid input, only integer input are valid

# %%
try:
    username = int(input("Enter your username"))
    password = int(input("Enter your password"))
    if username == correct_username and password == correct_password:
        print("login successful")
        break
    else:
        print("Give the correct username anandnd
except Exception as e:
        print(f"An error occurred: {e}")

# %%
i = i stores the current value of the i which is called late binding
